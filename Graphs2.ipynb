# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

# %%
#C600 Permeance 

data = {
    'Temperature': [20, 85, 150, 175, 200],
    'H2_5barg': [8.898e-08, 1.073e-07, 1.088e-07, 1.074e-07, 1.084e-07],
    'H2_4barg': [8.865e-08, 1.083e-07, 1.107e-07, 1.104e-07, 1.109e-07],
    'H2_3barg': [8.962e-08, 1.091e-07, 1.084e-07, 1.094e-07, 1.061e-07],
    'H2_2barg': [9.115e-08, 1.121e-07, 1.123e-07, 1.082e-07, 1.083e-07],
    'H2_1barg': [7.656e-08, 1.144e-07, 1.082e-07, 1.106e-07, 1.117e-07],
    'N2_5barg': [7.664E-10, 1.547E-09, 3.295E-09, 4.330E-09, 6.430E-09],
    'N2_4barg': [7.961E-10, 1.543E-09, 3.303E-09, 4.275E-09, 6.005E-09],
    'N2_3barg': [7.361E-10, 1.516E-09, 3.190E-09, 4.257E-09, 5.902E-09],
    'N2_2barg': [7.516E-10, 1.630E-09, 3.228E-09, 4.242E-09, 6.159E-09],
    'N2_1barg': [7.180E-10, 1.361E-09, 3.104E-09, 4.076E-09, 5.917E-09],
    'He_5barg': [4.956E-08, 5.787E-08, 6.150E-08, 6.269E-08, 6.209E-08],
    'He_4barg': [5.010E-08, 5.898E-08, 6.024E-08, 6.096E-08, 6.190E-08],
    'He_3barg': [5.050E-08, 5.877E-08, 6.228E-08, 6.223E-08, 6.490E-08],
    'He_2barg': [5.230E-08, 5.811E-08, 6.190E-08, 6.364E-08, 6.429E-08],
    'He_1barg': [4.936E-08, 5.922E-08, 6.191E-08, 6.501E-08, 6.764E-08],
    "CH4_5barg": [1.027E-10, 1.033E-10, 1.394E-09, 2.143E-09, 3.804E-09],
    "CH4_4barg": [1.291E-10, 1.291E-10, 1.528E-09, 2.171E-09, 3.713E-09],
    "CH4_3barg": [1.722E-10, 1.722E-10, 1.578E-09, 2.296E-09, 3.693E-09],
    "CH4_2barg": [2.583E-10, 2.583E-10, 1.568E-09, 2.405E-09, 3.917E-09],
    "CH4_1barg": [5.166E-10, 5.166E-10, 1.433E-09, 2.389E-09, 3.843E-09]

}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Plotting H2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[1:6]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C600 N2 Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

# Plotting N2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[6:11]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C600 N2 Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

# Plotting He Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[11:16]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C600 He Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
for column in df.columns[16:]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPI)")
plt.title("C600 CH4 Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

# %%
#C700

data = {
    "Temperature" :[20,85,150,175,200],
    "N2_5barg": [7.874E-11, 7.874E-11, 7.811E-11, 7.748E-11, 1.905E-10],
    "N2_4barg": [9.685E-11, 9.685E-11, 9.685E-11, 9.685E-11, 1.186E-10],
    "N2_3barg": [1.291E-10, 1.291E-10, 1.291E-10, 1.291E-10, 1.291E-10],
    "N2_2barg": [1.937E-10, 1.937E-10, 1.937E-10, 1.937E-10, 1.937E-10],
    "N2_1barg": [3.874E-10, 3.874E-10, 3.874E-10, 3.874E-10, 3.874E-10],
    "H2_5barg": [8.083E-09, 2.157E-08, 4.695E-08, 6.033E-08, 7.596E-08],
    "H2_4barg": [7.739E-09, 2.348E-08, 4.589E-08, 5.763E-08, 7.467E-08],
    "H2_3barg": [7.923E-09, 2.304E-08, 4.852E-08, 5.771E-08, 7.374E-08],
    "H2_2barg": [8.189E-09, 2.306E-08, 4.745E-08, 5.798E-08, 7.580E-08],
    "H2_1barg": [7.187E-09, 2.224E-08, 4.732E-08, 5.598E-08, 7.789E-08],
    "He_5barg": [1.129E-08, 2.795E-08, 4.819E-08, 5.464E-08, 6.160E-08],
    "He_4barg": [1.142E-08, 2.922E-08, 4.840E-08, 5.463E-08, 6.058E-08],
    "He_3barg": [1.143E-08, 2.872E-08, 4.862E-08, 5.675E-08, 6.425E-08],
    "He_2barg": [1.624E-08, 2.789E-08, 4.923E-08, 5.241E-08, 6.117E-08],
    "He_1barg": [1.121E-08, 3.254E-08, 4.587E-08, 5.393E-08, 6.102E-08],
    "CH4_5barg": [7.702E-11, 7.748E-11, 7.748E-11, 7.748E-11, 7.748E-11],
    "CH4_4barg": [9.685E-11, 9.685E-11, 9.685E-11, 9.685E-11, 9.685E-11],
    "CH4_3barg": [1.291E-10, 1.291E-10, 1.291E-10, 1.291E-10, 1.291E-10],
    "CH4_2barg": [1.937E-10, 1.937E-10, 1.937E-10, 1.937E-10, 1.937E-10],
    "CH4_1barg": [3.874E-10, 3.874E-10, 3.874E-10, 3.874E-10, 3.874E-10],
}


# Convert data to DataFrame
df = pd.DataFrame(data)

# Plotting N2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[1:6]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C700 N2 Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

# Plotting H2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[6:11]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C700 H2 Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

# Plotting He Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[11:16]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C700 He Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
for column in df.columns[16:]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C700 CH4 Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

# %%
#C800

data = {
    "Temperature" : [20, 85, 150, 175, 200],
    "N2_5barg": [6.299E-11, 6.224E-11, 6.249E-11, 6.199E-11, 6.457E-11],
    "N2_4barg": [7.748E-11, 7.748E-11, 7.748E-11, 7.748E-11, 7.748E-11],
    "N2_3barg": [1.033E-10, 1.033E-10, 1.033E-10, 1.033E-10, 1.033E-10],
    "N2_2barg": [1.550E-10, 1.550E-10, 1.550E-10, 1.550E-10, 1.550E-10],
    "N2_1barg": [3.099E-10, 3.099E-10, 3.099E-10, 3.099E-10, 3.099E-10],
    "H2_5barg": [8.026E-11, 1.527E-10, 2.397E-10, 2.316E-10, 2.339E-10],
    "H2_4barg": [7.748E-11, 7.748E-11, 1.984E-10, 2.034E-10, 2.065E-10],
    "H2_3barg": [1.033E-10, 1.033E-10, 1.033E-10, 1.829E-10, 2.157E-10],
    "H2_2barg": [1.550E-10, 1.550E-10, 1.550E-10, 1.550E-10, 2.572E-10],
    "H2_1barg": [3.099E-10, 3.099E-10, 3.099E-10, 3.099E-10, 3.099E-10],
    "He_5barg": [6.162E-11, 1.149E-10, 1.590E-10, 2.318E-10, 3.006E-10],
    "He_4barg": [7.748E-11, 7.748E-11, 1.964E-10, 2.181E-10, 2.878E-10],
    "He_3barg": [1.033E-10, 1.033E-10, 1.627E-10, 1.911E-10, 2.707E-10],
    "He_2barg": [1.550E-10, 1.550E-10, 1.550E-10, 1.550E-10, 2.286E-10],
    "He_1barg": [3.099E-10, 3.099E-10, 3.099E-10, 3.099E-10, 3.099E-10],
    "CH4_5barg": [6.430E-11, 6.236E-11, 6.199E-11, 6.199E-11, 6.199E-11],
    "CH4_4barg": [7.748E-11, 7.748E-11, 7.748E-11, 7.748E-11, 7.748E-11],
    "CH4_3barg": [1.033E-10, 1.033E-10, 1.033E-10, 1.033E-10, 1.033E-10],
    "CH4_2barg": [1.550E-10, 1.550E-10, 1.550E-10, 1.550E-10, 1.550E-10],
    "CH4_1barg": [3.099E-10, 3.099E-10, 3.099E-10, 3.099E-10, 3.099E-10],
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Plotting N2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[1:6]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C800 N2 Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

# Plotting H2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[6:11]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C800 H2 Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

# Plotting He Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[11:16]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C800 He Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
for column in df.columns[16:]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C800 CH4 Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

# %%
#C900

data = {
    "Temperature" : [20, 85, 150, 175, 200],
    "N2_5barg": [8.451E-11, 8.382E-11, 8.265E-11, 8.265E-11, 8.609E-11],
    "N2_4barg": [1.033E-10, 1.033E-10, 1.033E-10, 1.033E-10, 1.033E-10],
    "N2_3barg": [1.377E-10, 1.377E-10, 1.377E-10, 1.377E-10, 1.377E-10],
    "N2_2barg": [2.066E-10, 2.066E-10, 2.066E-10, 2.066E-10, 2.066E-10],
    "N2_1barg": [4.132E-10, 4.132E-10, 4.132E-10, 4.132E-10, 4.132E-10],
    "H2_5barg": [8.718E-11, 8.627E-11, 8.755E-11, 8.774E-11, 2.118E-10],
    "H2_4barg": [1.033E-10, 1.033E-10, 1.033E-10, 1.033E-10, 2.015E-10],
    "H2_3barg": [1.377E-10, 1.377E-10, 1.377E-10, 1.377E-10, 1.377E-10],
    "H2_2barg": [2.066E-10, 2.066E-10, 2.066E-10, 2.066E-10, 2.066E-10],
    "H2_1barg": [4.132E-10, 4.132E-10, 4.132E-10, 4.132E-10, 4.132E-10],
    "He_5barg": [8.434E-11, 8.281E-11, 8.365E-11, 8.332E-11, 8.265E-11],
    "He_4barg": [1.033E-10, 1.033E-10, 1.033E-10, 1.033E-10, 1.033E-10],
    "He_3barg": [1.377E-10, 1.377E-10, 1.377E-10, 1.377E-10, 1.377E-10],
    "He_2barg": [2.066E-10, 2.066E-10, 2.066E-10, 2.066E-10, 2.066E-10],
    "He_1barg": [4.132E-10, 4.132E-10, 4.132E-10, 4.132E-10, 4.132E-10],
    "CH4_5barg": [8.574E-11, 8.315E-11, 8.265E-11, 8.265E-11, 8.265E-11],
    "CH4_4barg": [1.033E-10, 1.033E-10, 1.033E-10, 1.033E-10, 1.033E-10],
    "CH4_3barg": [1.377E-10, 1.377E-10, 1.377E-10, 1.377E-10, 1.377E-10],
    "CH4_2barg": [2.066E-10, 2.066E-10, 2.066E-10, 2.066E-10, 2.066E-10],
    "CH4_1barg": [4.132E-10, 4.132E-10, 4.132E-10, 4.132E-10, 4.132E-10],
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Plotting N2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[1:6]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C800 N2 Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

# Plotting H2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[6:11]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C800 H2 Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

# Plotting He Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[11:16]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C800 He Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
for column in df.columns[16:]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("Permeance (GPU)")
plt.title("C800 CH4 Permeance vs Temperature")
plt.legend()
plt.grid(True)
plt.show()

# %%
#C600 kinetic diameter

data = {
    'Kinetic Diameter (pm)' : [260,289,364,380],
    '20C-5barg': [4.956e-8, 8.898e-8, 7.664e-10, 1.027e-10],
    '20C-4barg': [5.010e-8, 8.865e-8, 7.961e-10, 1.291e-10],
    '20C-3barg': [5.050e-8, 8.962e-8, 7.361e-10, 1.722e-10],
    '20C-2barg': [5.230e-8, 9.115e-8, 7.516e-10, 2.583e-10],
    '20C-1barg': [4.936e-8, 7.645e-8, 7.180e-10, 5.166e-10],
    '85C-5barg': [5.787e-8, 1.073e-7, 1.547e-9, 1.033e-10],
    '85C-4barg': [5.898e-8, 1.083e-7, 1.543e-9, 1.291e-10],
    '85C-3barg': [5.877e-8, 1.091e-7, 1.516e-9, 1.722e-10],
    '85C-2barg': [5.811e-8, 1.121e-7, 1.630e-9, 2.583e-10],
    '85C-1barg': [5.922e-8, 1.144e-7, 1.361e-9, 5.166e-10],
    '150C-5barg': [6.150e-8, 1.088e-7, 3.295e-9, 1.394e-9],
    '150C-4barg': [6.024e-8, 1.107e-7, 3.303e-9, 1.528e-9],
    '150C-3barg': [6.228e-8, 1.084e-7, 3.190e-9, 1.578e-9],
    '150C-2barg': [6.190e-8, 1.123e-7, 3.228e-9, 1.568e-9],
    '150C-1barg': [6.191e-8, 1.082e-7, 3.104e-9, 1.433e-9],
    '175C-5barg': [6.269e-8, 1.074e-7, 4.330e-9, 2.143e-9],
    '175C-4barg': [6.096e-8, 1.104e-7, 4.275e-9, 2.171e-9],
    '175C-3barg': [6.223e-8, 1.094e-7, 4.257e-9, 2.296e-9],
    '175C-2barg': [6.364e-8, 1.082e-7, 4.242e-9, 2.405e-9],
    '175C-1barg': [6.501e-8, 1.106e-7, 4.076e-9, 2.389e-9],
    '200C-5barg': [6.209e-8, 1.084e-7, 6.430e-9, 3.804e-9],
    '200C-4barg': [6.190e-8, 1.109e-7, 6.005e-9, 3.713e-9],
    '200C-3barg': [6.490e-8, 1.061e-7, 5.902e-9, 3.693e-9],
    '200C-2barg': [6.429e-8, 1.083e-7, 6.159e-9, 3.917e-9],
    '200C-1barg': [6.764e-8, 1.117e-7, 5.917e-9, 3.843e-9],
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Add labels for each kinetic diameter
labels = ["He", "H2", "N2", "CH4"]

# Plot all temperatures
plt.figure(figsize=(15, 10))
for column in df.columns[16:]:  
    plt.plot(df['Kinetic Diameter (pm)'], df[column], label=column, marker='o')
for i, txt in enumerate(labels):
    plt.annotate(txt, (df['Kinetic Diameter (pm)'][i], 0), textcoords="offset points", xytext=(0,10), ha='center')
plt.xlabel("Kinetic Diameter (pm)")
plt.ylabel("Permeance (GPU)")
plt.title("Permeance vs Kinetic Diameter C600")
plt.legend()
plt.grid(True)
plt.show()

# Plot for 20C
plt.figure(figsize=(12, 8))
for column in df.columns[1:6]:  
    plt.plot(df['Kinetic Diameter (pm)'], df[column], label=column, marker='o')
for i, txt in enumerate(labels):
    plt.annotate(txt, (df['Kinetic Diameter (pm)'][i], 0), textcoords="offset points", xytext=(0,10), ha='center')
plt.xlabel("Kinetic Diameter (pm)")
plt.ylabel("Permeance (GPU)")
plt.title("Permeance vs Kinetic Diameter C600 at 20C")
plt.legend()
plt.grid(True)
plt.show()

# Plot for 85C
plt.figure(figsize=(12, 8))
for column in df.columns[6:11]:  
    plt.plot(df['Kinetic Diameter (pm)'], df[column], label=column, marker='o')
for i, txt in enumerate(labels):
    plt.annotate(txt, (df['Kinetic Diameter (pm)'][i], 0), textcoords="offset points", xytext=(0,10), ha='center')
plt.xlabel("Kinetic Diameter (pm)")
plt.ylabel("Permeance (GPU)")
plt.title("Permeance vs Kinetic Diameter C600 at 85C")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 8))
for column in df.columns[11:16]:  
    plt.plot(df['Kinetic Diameter (pm)'], df[column], label=column, marker='o')
for i, txt in enumerate(labels):
    plt.annotate(txt, (df['Kinetic Diameter (pm)'][i], 0), textcoords="offset points", xytext=(0,10), ha='center')
plt.xlabel("Kinetic Diameter (pm)")
plt.ylabel("Permeance (GPU)")
plt.title("Permeance vs Kinetic Diameter C600 at 150C")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 8))
for column in df.columns[16:21]:  
    plt.plot(df['Kinetic Diameter (pm)'], df[column], label=column, marker='o')
for i, txt in enumerate(labels):
    plt.annotate(txt, (df['Kinetic Diameter (pm)'][i], 0), textcoords="offset points", xytext=(0,10), ha='center')
plt.xlabel("Kinetic Diameter (pm)")
plt.ylabel("Permeance (GPU)")
plt.title("Permeance vs Kinetic Diameter C600 at 185C")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 8))
for column in df.columns[21:]:  
    plt.plot(df['Kinetic Diameter (pm)'], df[column], label=column, marker='o')
for i, txt in enumerate(labels):
    plt.annotate(txt, (df['Kinetic Diameter (pm)'][i], 0), textcoords="offset points", xytext=(0,10), ha='center')
plt.xlabel("Kinetic Diameter (pm)")
plt.ylabel("Permeance (GPU)")
plt.title("Permeance vs Kinetic Diameter C600 at 200C")
plt.legend()
plt.grid(True)
plt.show()
