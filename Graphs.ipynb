# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

# %%
data = {
    'Temperature': [20, 85, 150, 175, 200],
    'N2_permeability_C600_5_barg': [2, 5, 10, 13, 19],
    'N2_permeability_C600_4_barg': [2, 5, 10, 13, 18],
    'N2_permeability_C600_3_barg': [2, 5, 10, 13, 18],
    'N2_permeability_C600_2_barg': [2, 5, 10, 13, 18],
    'N2_permeability_C600_1_barg': [2, 5, 10, 13, 19],
    'H2_permeability_C600_5_barg': [266, 320, 325, 321, 324],
    'H2_permeability_C600_4_barg': [265, 323, 331, 330, 331],
    'H2_permeability_C600_3_barg': [268, 326, 324, 327, 317],
    'H2_permeability_C600_2_barg': [268, 326, 324, 327, 317],
    'H2_permeability_C600_1_barg': [228, 341, 323, 330, 333],
    'He_permeability_C600_5_barg': [148, 173, 184, 187, 185],
    'He_permeability_C600_4_barg': [150, 176, 180, 182, 185],
    'He_permeability_C600_3_barg': [151, 175, 186, 186, 194],
    'He_permeability_C600_2_barg': [156, 173, 185, 190, 192],
    'He_permeability_C600_1_barg': [147, 177, 185, 194, 202],
    'CH4_permeability_C600_5_barg': [0, 0, 4, 5, 11],
    'CH4_permeability_C600_4_barg': [0, 0, 5, 6, 11],
    'CH4_permeability_C600_3_barg': [1, 1, 5, 7, 11],
    'CH4_permeability_C600_2_barg': [1, 1, 5, 7, 12],
    'CH4_permeability_C600_1_barg': [2, 2, 4, 7, 11]
}


# Convert data to DataFrame
df = pd.DataFrame(data)

# Plotting N2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[1:6]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("N2 Peremability")
plt.title("C600 N2 Peremability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

# Plotting H2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[6:11]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("H2 Peremability")
plt.title("C600 H2 Peremability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

# Plotting He Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[11:16]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("He Peremability")
plt.title("C600 He Peremability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
for column in df.columns[16:]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("CH4 Peremability")
plt.title("C600 CH4 Peremability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

# %%
data = {
    'Temperature': [20, 85, 150, 175, 200],
    'N2_permeability_C700_5_barg': [0, 0, 0, 0, 1],
    'N2_permeability_C700_4_barg': [0, 0, 0, 0, 0],
    'N2_permeability_C700_3_barg': [0, 0, 0, 0, 0],
    'N2_permeability_C700_2_barg': [1, 1, 1, 1, 1],
    'N2_permeability_C700_1_barg': [1, 1, 1, 1, 1],
    'H2_permeability_C700_5_barg': [24, 64, 140, 180, 227],
    'H2_permeability_C700_4_barg': [23, 70, 137, 172, 223],
    'H2_permeability_C700_3_barg': [24, 69, 145, 172, 223],
    'H2_permeability_C700_2_barg': [24, 69, 142, 173, 226],
    'H2_permeability_C700_1_barg': [21, 66, 141, 167, 233],
    'He_permeability_C700_5_barg': [34, 83, 144, 163, 184],
    'He_permeability_C700_4_barg': [34, 87, 144, 163, 181],
    'He_permeability_C700_3_barg': [34, 86, 145, 169, 192],
    'He_permeability_C700_2_barg': [48, 83, 147, 156, 183],
    'He_permeability_C700_1_barg': [33, 97, 137, 161, 182],
    'CH4_permeability_C700_5_barg': [0, 0, 0, 0, 0],
    'CH4_permeability_C700_4_barg': [0, 0, 0, 0, 0],
    'CH4_permeability_C700_3_barg': [0, 0, 0, 0, 0],
    'CH4_permeability_C700_2_barg': [1, 1, 1, 1, 1],
    'CH4_permeability_C700_1_barg': [1, 1, 1, 1, 1]
}


# Convert data to DataFrame
df = pd.DataFrame(data)

# Plotting N2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[1:6]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("N2 Permeability")
plt.title("C700 N2 Permeability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

# Plotting H2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[6:11]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("H2 Permeability")
plt.title("C700 H2 Permeability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

# Plotting He Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[11:16]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("He Permeability")
plt.title("C700 He Permeability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
for column in df.columns[16:]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("CH4 Permeability")
plt.title("C700 CH4 Permeability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Updating data to the provided new values and changing names to C800

# Updating the provided data, changing "Permeate" to "Permeability" in column names

data = {
    'Temperature': [20, 85, 150, 175, 200],
    'N2_permeability_C800_5_barg': [0, 0, 0, 0, 0],
    'N2_permeability_C800_4_barg': [0, 0, 0, 0, 0],
    'N2_permeability_C800_3_barg': [0, 0, 0, 0, 0],
    'N2_permeability_C800_2_barg': [0, 0, 0, 0, 0],
    'N2_permeability_C800_1_barg': [1, 1, 1, 1, 1],
    'H2_permeability_C800_5_barg': [0, 0, 0, 1, 1],
    'H2_permeability_C800_4_barg': [0, 0, 1, 1, 1],
    'H2_permeability_C800_3_barg': [0, 0, 0, 1, 1],
    'H2_permeability_C800_2_barg': [0, 0, 0, 0, 1],
    'H2_permeability_C800_1_barg': [1, 1, 1, 1, 1],
    'He_permeability_C800_5_barg': [0, 0, 0, 1, 1],
    'He_permeability_C800_4_barg': [0, 0, 1, 1, 1],
    'He_permeability_C800_3_barg': [0, 0, 0, 1, 1],
    'He_permeability_C800_2_barg': [0, 0, 0, 0, 1],
    'He_permeability_C800_1_barg': [1, 1, 1, 1, 1],
    'CH4_permeability_C800_5_barg': [0, 0, 0, 0, 0],
    'CH4_permeability_C800_4_barg': [0, 0, 0, 0, 0],
    'CH4_permeability_C800_3_barg': [0, 0, 0, 0, 0],
    'CH4_permeability_C800_2_barg': [0, 0, 0, 0, 0],
    'CH4_permeability_C800_1_barg': [1, 1, 1, 1, 1]
}


# Convert data to DataFrame
df = pd.DataFrame(data)

# Plotting N2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[1:6]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("N2 Permeability")
plt.title("C800 N2 Permeability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

# Plotting H2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[6:11]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("H2 Permeability")
plt.title("C800 H2 Permeability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

# Plotting He Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[11:16]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("He Permeability")
plt.title("C800 He Permeability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
for column in df.columns[16:]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("CH4 Permeability")
plt.title("C800 CH4 Permeability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

# %%
data = {
    'Temperature': [20, 85, 150, 175, 200],
    'N2_permeability_C900_5_barg': [0, 0, 0, 0, 0],
    'N2_permeability_C900_4_barg': [0, 0, 0, 0, 0],
    'N2_permeability_C900_3_barg': [0, 0, 0, 0, 0],
    'N2_permeability_C900_2_barg': [1, 1, 1, 1, 1],
    'N2_permeability_C900_1_barg': [1, 1, 1, 1, 1],
    'H2_permeability_C900_5_barg': [0, 0, 0, 0, 1],
    'H2_permeability_C900_4_barg': [0, 0, 0, 0, 1],
    'H2_permeability_C900_3_barg': [0, 0, 0, 0, 0],
    'H2_permeability_C900_2_barg': [1, 1, 1, 1, 1],
    'H2_permeability_C900_1_barg': [1, 1, 1, 1, 1],
    'He_permeability_C900_5_barg': [0, 0, 0, 0, 0],
    'He_permeability_C900_4_barg': [0, 0, 0, 0, 0],
    'He_permeability_C900_3_barg': [0, 0, 0, 0, 0],
    'He_permeability_C900_2_barg': [1, 1, 1, 1, 1],
    'He_permeability_C900_1_barg': [1, 1, 1, 1, 1],
    'CH4_permeability_C900_5_barg': [0, 0, 0, 0, 0],
    'CH4_permeability_C900_4_barg': [0, 0, 0, 0, 0],
    'CH4_permeability_C900_3_barg': [0, 0, 0, 0, 0],
    'CH4_permeability_C900_2_barg': [1, 1, 1, 1, 1],
    'CH4_permeability_C900_1_barg': [1, 1, 1, 1, 1]
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Plotting N2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[1:6]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("N2 Permeability")
plt.title("C800 N2 Permeability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

# Plotting H2 Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[6:11]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("H2 Permeability")
plt.title("C800 H2 Permeability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

# Plotting He Permeate vs Temperature
plt.figure(figsize=(8, 6))
for column in df.columns[11:16]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("He Permeability")
plt.title("C800 He Permeability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
for column in df.columns[16:]:  
    plt.plot(df['Temperature'], df[column], label=column, marker='o')
plt.xlabel("Temperature (°C)")
plt.ylabel("CH4 Permeability")
plt.title("C800 CH4 Permeability vs Temperature for Different Samples")
plt.legend()
plt.grid(True)
plt.show()

# %%
#PERMEANCE

# Updating the provided data to replace "Permeability" with "Permeance" for C600

data = {
    'Temperature': [20, 85, 150, 175, 200],
    'N2_permeance_C600_5_barg': [2, 5, 10, 13, 19],
    'N2_permeance_C600_4_barg': [2, 5, 10, 13, 18],
    'N2_permeance_C600_3_barg': [2, 5, 10, 13, 18],
    'N2_permeance_C600_2_barg': [2, 5, 10, 13, 18],
    'N2_permeance_C600_1_barg': [2, 5, 10, 13, 19],
    'H2_permeance_C600_5_barg': [266, 320, 325, 321, 324],
    'H2_permeance_C600_4_barg': [265, 323, 331, 330, 331],
    'H2_permeance_C600_3_barg': [268, 326, 324, 327, 317],
    'H2_permeance_C600_2_barg': [268, 326, 324, 327, 317],
    'H2_permeance_C600_1_barg': [228, 341, 323, 330, 333],
    'He_permeance_C600_5_barg': [148, 173, 184, 187, 185],
    'He_permeance_C600_4_barg': [150, 176, 180, 182, 185],
    'He_permeance_C600_3_barg': [151, 175, 186, 186, 194],
    'He_permeance_C600_2_barg': [156, 173, 185, 190, 192],
    'He_permeance_C600_1_barg': [147, 177, 185, 194, 202],
    'CH4_permeance_C600_5_barg': [0, 0, 4, 5, 11],
    'CH4_permeance_C600_4_barg': [0, 0, 5, 6, 11],
    'CH4_permeance_C600_3_barg': [1, 1, 5, 7, 11],
    'CH4_permeance_C600_2_barg': [1, 1, 5, 7, 12],
    'CH4_permeance_C600_1_barg': [2, 2, 4, 7, 11]
}
